# %%
with open('june5/att.csv','r') as ry:
    s=ry.readline()
     for i in s:
        a=i.split("/n")
        print(a)
# Out:
#   File "<ipython-input-14-a04f08c49ff2>", line 3
#     for i in s:
#     ^
# IndentationError: unexpected indent

# %%
with open('june5/att.csv','r') as r:
    s=r.readlines()
    for i in s:
        a=i.split("/n")
        b=a[0].split("-")[0]
        print(b[0:14])
# Out:
# internship pub
# Summary,,,,,,
#
# Meeting Date,M
# "May 24, 2021
# ,,,,,,
#
# Details,,,,,,
#
# Name,Email Add
#  191af112 Alex
# 00038
# 121810310018
# 16491A04C5
# 168A1A0455
# 18091A04H9
# 18091A04H9
# 181FA06009 Sir
# 181FA06009
# 18471A0551(Sha
# 18471A0551
# 18691A04E8
# 18691A0544
# 18761A0479
# "1881951044
# 18BF1A05C3
# 18BF1A05C4
# 18BF1A05C4
# 18F01A0548
# 18FE1A05A1
# 18FE1A05A7
# 18FE1A05B7
# 18FE1A05B7
# 18HT1A0519
# 19005A0503
# "19005A0520
# 19005A0521
# 19131a05n2
# 192U1A0514
# 19695A0514
# 19695A0514
# "19765A0501,lo
# 19765A0501
# 199w1f0074
# 199w1f0074
# 19BQ1A0536
# 19BQ1A0536
# 19BQ1A0551
# 19BQ1A0551
# 19BQ1A0551
# 19KQ1A0502
# 19KQ1A0504 G.V
# 19KQ1A0504 G.V
# 19KQ1A0504 G.V
# 19KQ1A0504
# 19KQ1A0505
# 19KQ1A0506
# 19KQ1A0506
# 19KQ1A0507
# 19KQ1A0508 Kan
# 19KQ1A0508
# 19KQ1A0511
# 19KQ1A0518
# 19KQ1A0519
# 19KQ1A0521 sou
# 19KQ1A0521
# 19KQ1A0522
# 19KQ1A0523
# 19KQ1A0526
# 19KQ1A0528
# 19KQ1A0528
# 19KQ1A0530
# 19KQ1A0532
# 19KQ1A0534
# 19KQ1A0541
# ...

# %%
with open('june5/att.csv','r') as r:
    s=r.readlines()
    for i in s:
        
        a=i.split("-")[0]
        print(a)
# Out:
# internship public's Meeting Attendees,,,,,,GoToMeeting
#
# Summary,,,,,,
#
# Meeting Date,Meeting Duration,Number of Attendees,Meeting ID,,,
#
# "May 24, 2021 3:59 AM PDT",158 minutes,146,183
# ,,,,,,
#
# Details,,,,,,
#
# Name,Email Address,Join Time,Leave Time,Time in Session (minutes),,
#
#  191af112 Alex,siripalakiti2000@gmail.com,4:27 AM,5:05 AM,37,,
#
# 00038
# 121810310018
# 16491A04C5
# 168A1A0455
# 18091A04H9
# 18091A04H9
# 181FA06009 Sirisha Vignan University,sirishachennamsetti18@gmail.com,4:00 AM,4:13 AM,13,,
#
# 181FA06009
# 18471A0551(Sharukh) NEC,sharukh.shaik1020@gmail.com,4:00 AM,4:11 AM,11,,
#
# 18471A0551
# 18691A04E8
# 18691A0544
# 18761A0479
# "1881951044
# 18BF1A05C3
# 18BF1A05C4
# 18BF1A05C4
# 18F01A0548
# 18FE1A05A1
# 18FE1A05A7
# 18FE1A05B7
# 18FE1A05B7
# 18HT1A0519
# 19005A0503
# "19005A0520
# 19005A0521
# 19131a05n2
# 192U1A0514
# 19695A0514
# 19695A0514
# "19765A0501,lokesh,lbrce",19765A0501@lbrce.ac.in,4:00 AM,4:04 AM,3,,
#
# 19765A0501
# 199w1f0074
# ...
